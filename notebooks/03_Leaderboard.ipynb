# %% [markdown]
# # 03 — Model Leaderboard (Unified Holdout)

# %%
from src.evaluate import leaderboard
path, lb = leaderboard('data','artifacts', holdout_weeks=8, topN_series=10)
path

# %%
import pandas as pd
lb = pd.read_csv('artifacts/leaderboard.csv')
lb

# %%
ax = lb.pivot_table(index='Model', values='WMAE', aggfunc='mean').sort_values('WMAE').plot(kind='bar', figsize=(10,4), title='Mean WMAE by Model')
